# %% [markdown]
# <a href="https://colab.research.google.com/github/Alirazakhan18733/DATA-SCIENCE-MASTER/blob/main/Bokeh.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bokeh
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import bokeh.io
import bokeh.plotting
bokeh.io.output_notebook()

# %%
from bokeh.plotting import figure, output_file, show                
from bokeh.sampledata.iris import flowers

# %%
flowers
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
p = figure(title = 'test flower')
p.xaxis.axis_label = 'petal_length'
p.yaxis.axis_label = 'petal_width'
p.circle(flowers['petal_length'], flowers['petal_width'])
show(p)
# Out:
#   <div class="bk-root" id="09d1e08e-552a-417c-ae69-179c6e37360a" data-root-id="5630"></div>

# %%
p = figure(title = 'test flower')
p.xaxis.axis_label = 'petal_length'
p.yaxis.axis_label = 'petal_width'
p.line(flowers['petal_length'], flowers['petal_width'])
show(p)
# Out:
#   <div class="bk-root" id="700e7f3f-8435-4bdc-a8b0-71beefc111c3" data-root-id="3382"></div>

# %%
x=[3,4,5,6,7]
y=[4,5,6,7,4]
output_file('line.html')
p=figure(title="Line graph")
p.line(x,y)
show(p)
# Out:
#   <div class="bk-root" id="16d7d7e3-1e3f-427f-aaad-76c18b1d64e6" data-root-id="3728"></div>

# %%
x=[3,4,5,6,7]
y=[4,5,6,7,4]
output_file('line.html')
p=figure(title="Line graph")
p.scatter(x,y,size=20,fill_color='red',legend_label='This is my data points')
show(p)
# Out:
#   <div class="bk-root" id="a7adebfe-3461-4d05-b090-90a00db606bf" data-root-id="4948"></div>
